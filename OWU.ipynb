# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %%
OWU_game = pd.read_csv("Game 15 OWU.xlsx - OWU.csv")

# %%
OWU_full = OWU_game[OWU_game['Split Name']== 'game']
OWU_full
# Out:
#    Session Title Player Name  Minutes Played Split Name  Distance (miles)  \
# 0            OWU           O             0.0       game            0.1535
# 1            OWU           A             0.0       game            0.1513
# 2            OWU           J            32.0       game            2.4101
# 3            OWU           Q            67.0       game            4.7929
# 4            OWU          B             17.0       game            1.3648
# 5            OWU           G            42.0       game            2.5185
# 6            OWU           I            48.0       game            3.8549
# 7            OWU           Z             0.0       game            0.2394
# 8            OWU           C            90.0       game            6.2563
# 9            OWU           N             0.0       game            0.1147
# 10           OWU           S            86.0       game            5.4805
# 11           OWU           H            46.0       game            3.1773
# 12           OWU           V            90.0       game            5.8264
# 13           OWU           R            90.0       game            5.7000
# 14           OWU           E            10.0       game            0.8408
# 15           OWU           X            90.0       game            2.1257
# 16           OWU          K             90.0       game            5.3529
# 17           OWU          L             90.0       game            5.6742
#
#    Player Name.1  Sprint Distance (yards) Player Name.2  Power Plays  \
# 0              O                   0.0000             O            0
# 1              A                   0.0000             A            0
# 2              J                  85.5859             J           19
# 3              Q                  93.5233             Q           26
# 4             B                  141.3917            B            12
# 5              G                 189.5653             G           27
# 6              I                 354.1054             I           38
# 7              Z                   0.0000             Z            0
# 8              C                  49.0823             C           26
# 9              N                   0.0000             N            0
# 10             S                 253.7624             S           41
# 11             H                 164.7141             H           29
# 12             V                 126.3502             V           33
# 13             R                 407.8509             R           42
# 14             E                  26.7377             E            5
# 15             X                  13.9993             X            2
# 16            K                  350.7809            K            45
# 17            L                  233.4956            L            31
#
#     Energy (kcal)  ...  Accelerations Zone Count: 3 - 4 m/s/s  \
# 0         18.1199  ...                                      0
# 1         22.2237  ...                                      0
# 2        471.2090  ...                                     19
# 3       1011.3102  ...                                     21
# 4        240.5307  ...                                      7
# 5        422.5878  ...                                     19
# 6        563.0843  ...                                     19
# 7         32.5113  ...                                      0
# 8       1105.7095  ...                                     45
# 9         19.0553  ...                                      0
# 10      1017.5912  ...                                     45
# 11       519.1016  ...                                     22
# 12      1037.1944  ...                                     35
# 13       964.2353  ...                                     25
# 14       167.7553  ...                                      6
# 15       409.5611  ...                                     12
# 16       978.6159  ...                                     34
# 17       970.6513  ...                                     49
#
#     Accelerations Zone Count: > 4 m/s/s  Deceleration Zone Count: 0 - 1 m/s/s  \
# 0                                     0                                     0
# 1                                     0                                     0
# 2                                     5                                     0
# 3                                     1                                     0
# 4                                     2                                     0
# 5                                     3                                     0
# 6                                     8                                     0
# 7                                     0                                     0
# 8                                    13                                     0
# 9                                     0                                     0
# 10                                   12                                     0
# 11                                    6                                     0
# 12                                    7                                     0
# 13                                    7                                     0
# 14                                    2                                     0
# 15                                    4                                     0
# 16                                   14                                     0
# 17                                    8                                     0
#
#     Deceleration Zone Count: 1 - 2 m/s/s Deceleration Zone Count: 2 - 3 m/s/s  \
# 0                                      0                                    0
# 1                                      0                                    0
# 2                                     94                                   48
# 3                                    190                                   93
# 4                                     41                                   23
# 5                                     98                                   53
# 6                                    149                                   64
# 7                                      1                                    0
# 8                                    352                                  149
# 9                                      0                                    0
# 10                                   223                                  129
# 11                                   111                                   49
# 12                                   302                                  142
# 13                                   179                                  130
# 14                                    49                                   23
# 15                                    53                                   25
# 16                                   241                                   94
# 17                                   281                                  132
#
#     Deceleration Zone Count: 3 - 4 m/s/s  Deceleration Zone Count: > 4 m/s/s  \
# 0                                      0                                   0
# 1                                      0                                   0
# 2                                     25                                  13
# 3                                     41                                  24
# 4                                      8                                  10
# 5                                     20                                  15
# 6                                     26                                  22
# 7                                      0                                   0
# 8                                     44                                  28
# 9                                      0                                   0
# 10                                    66                                  24
# 11                                    28                                  25
# 12                                    37                                  17
# 13                                    56                                  20
# 14                                     5                                   3
# 15                                    10                                   6
# 16                                    26                                  24
# 17                                    46                                  18
#
#     Unnamed: 99  Unnamed: 100  Player Name.4
# 0           0.0           NaN              O
# 1           0.0           NaN              A
# 2          38.0          38.0              J
# 3          65.0          65.0              Q
# 4          18.0          18.0             B
# 5          35.0          35.0              G
# 6          48.0          48.0              I
# 7           0.0           NaN              Z
# 8          72.0          72.0              C
# 9           0.0           NaN              N
# 10         90.0          90.0              S
# 11         53.0          53.0              H
# 12         54.0          54.0              V
# 13         76.0          76.0              R
# 14          8.0           8.0              E
# 15         16.0          16.0              X
# 16         50.0          50.0             K
# 17         64.0          64.0             L
#
# [18 rows x 102 columns]

# %%
OWU_volume_intensity = OWU_full[["Player Name", "Minutes Played", "Distance (miles)", "Sprint Distance (yards)", "Power Plays", "Energy (kcal)", "Impacts", "Top Speed (mph)","Distance Per Min (yd/min)", "Power Score (w/kg)", "Player Load", "Work Ratio"]]

# %%
OWU_cluster = OWU_volume_intensity.loc[:, OWU_volume_intensity.columns != 'Player Name']

# %%
OWU_distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(OWU_cluster)
    OWU_distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, OWU_distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method shwoing the optimal k')
plt.show()

# %%
x_OWU = OWU_cluster.values # numpy array
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x_OWU)
X_norm = pd.DataFrame(x_scaled)

# %%
OWU_pca = PCA(n_components = 2) # 2D PCA for the plot
reduced_OWU = pd.DataFrame(OWU_pca.fit_transform(X_norm))

# %%
kmeans = KMeans(n_clusters=3)
# fit the input data
kmeans = kmeans.fit(reduced_OWU)
# get the cluster labels
labels = kmeans.predict(reduced_OWU)
# centroid values
centroid = kmeans.cluster_centers_
# cluster values
clusters = kmeans.labels_.tolist()
# adding names
OWU_names = OWU_full['Player Name']

# %%
reduced_OWU['cluster'] = clusters
reduced_OWU['names'] = OWU_names
reduced_OWU.columns = ['x', 'y', 'cluster', 'names']
reduced_OWU.head()

# %%
# %matplotlib inline
sns.set(style="white")
ax = sns.lmplot(x="x", y="y", hue='cluster', data = reduced_OWU, legend= True,
fit_reg=False, height = 15, scatter_kws={"s": 700})
texts = []
for x, y, s in zip(reduced_OWU.x, reduced_OWU.y, reduced_OWU.names):
    texts.append(plt.text(x, y, s))
ax.set(ylim=(-2, 2))
plt.tick_params(labelsize=15)
plt.xlabel("OWU PC 1", fontsize = 40)
plt.ylabel("OWU PC 2", fontsize = 40)
plt.title('OWU Clusters', fontsize=40)
plt.legend(fontsize = 20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9e5913c38d66> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 sns.set(style="white")
#       3 ax = sns.lmplot(x="x", y="y", hue='cluster', data = reduced_OWU, legend= True,
#       4 fit_reg=False, height = 15, scatter_kws={"s": 250})
#       5 texts = []
#
# NameError: name 'sns' is not defined

# %%
OWU_group_0 = reduced_OWU[(reduced_OWU['cluster'] == 0)]
OWU_group_0

# %%
OWU_group_1 = reduced_OWU[(reduced_OWU['cluster'] == 1)]
OWU_group_1

# %%
OWU_group_2 = reduced_OWU[(reduced_OWU['cluster'] == 2)]
OWU_group_2
