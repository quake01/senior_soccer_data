# %%
import pandas as pd
import numpy as np
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn import preprocessing
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Asbury_game = pd.read_csv("Game 10 Ashbury.xlsx - Asbury.csv")
Asbury_game = Asbury_game.loc[:, Asbury_game.columns != 'Player Name']

# %%
Asbury_full = Asbury_game[Asbury_game['Split Name']== 'game']
Asbury_full
# Out:
#    Session Title Player Code  Minutes Played Split Name  Distance (miles)  \
# 0         Asbury           M            90.0       game            4.7620
# 1         Asbury           V            53.0       game            4.3442
# 2         Asbury           E            63.0       game            2.0922
# 3         Asbury           C            40.0       game            3.1470
# 4         Asbury           N            13.0       game            0.9707
# 5         Asbury           K            90.0       game            5.1294
# 6         Asbury           R            85.0       game            5.7178
# 7         Asbury           H            41.0       game            3.2067
# 8         Asbury           P            49.0       game            2.7868
# 9         Asbury           G             0.0       game            0.1627
# 10        Asbury           Q            77.0       game            5.6968
# 11        Asbury           F            45.0       game            1.4701
# 12        Asbury           O             6.0       game            0.6851
# 13        Asbury           S            71.0       game            4.9192
# 14        Asbury           X            45.0       game            1.1985
# 15        Asbury           Z             5.0       game            0.6369
# 16        Asbury           L            90.0       game            6.3675
# 17        Asbury           U            41.0       game            3.1458
# 18        Asbury           A             5.0       game            0.4816
# 19        Asbury           I            74.0       game            5.3096
# 20        Asbury           J            40.0       game            2.9121
#
#     Sprint Distance (yards)  Power Plays  Energy (kcal)  Impacts  Hr Load  \
# 0                       282           30       732.7249        0        0
# 1                        50           12       777.6657        0        0
# 2                        34            7       414.4585        0        0
# 3                        91           19       566.0646        2        0
# 4                        49            6       199.8937        1        0
# 5                       152           28       920.7575        1        0
# 6                       293           34       962.9745        1        0
# 7                       169           28       522.5151        2        0
# 8                       182           23       508.0111        1        0
# 9                         0            0        22.2751        0        0
# 10                       48           34      1205.1208        2        0
# 11                        0            0       259.6690        0        0
# 12                       54            7       100.6404        0        0
# 13                      226           45       915.8153        2        0
# 14                        0            0       220.9361        0        0
# 15                       12            7       104.0915        0        0
# 16                      349           57      1120.6916        4        0
# 17                      254           34       516.9546        3        0
# 18                       60            3        83.2466        0        0
# 19                      228           50       776.0975        2        0
# 20                      118           29       572.9553        1        0
#
#     ...  Accelerations Zone Count: 1 - 2 m/s/s  \
# 0   ...                                    173
# 1   ...                                    261
# 2   ...                                    136
# 3   ...                                    185
# 4   ...                                     46
# 5   ...                                    230
# 6   ...                                    270
# 7   ...                                    138
# 8   ...                                    121
# 9   ...                                      0
# 10  ...                                    291
# 11  ...                                     52
# 12  ...                                     24
# 13  ...                                    202
# 14  ...                                     19
# 15  ...                                     26
# 16  ...                                    310
# 17  ...                                    127
# 18  ...                                     12
# 19  ...                                    259
# 20  ...                                    138
#
#     Accelerations Zone Count: 2 - 3 m/s/s  \
# 0                                     102
# 1                                     127
# 2                                      63
# 3                                      86
# 4                                      31
# 5                                     129
# 6                                      98
# 7                                      84
# 8                                      65
# 9                                       0
# 10                                    155
# 11                                     18
# 12                                     19
# 13                                    131
# 14                                     12
# 15                                     17
# 16                                    202
# 17                                     70
# 18                                      8
# 19                                    134
# 20                                     68
#
#     Accelerations Zone Count: 3 - 4 m/s/s  \
# 0                                      27
# 1                                      24
# 2                                       7
# 3                                      30
# 4                                       0
# 5                                      30
# 6                                      38
# 7                                      17
# 8                                      26
# 9                                       0
# 10                                     21
# 11                                      1
# 12                                      4
# 13                                     30
# 14                                      0
# 15                                      7
# 16                                     61
# 17                                     32
# 18                                      3
# 19                                     42
# 20                                     29
#
#     Accelerations Zone Count: > 4 m/s/s  Deceleration Zone Count: 0 - 1 m/s/s  \
# 0                                     4                                     0
# 1                                    11                                     0
# 2                                     4                                     0
# 3                                     7                                     0
# 4                                     2                                     0
# 5                                     7                                     0
# 6                                     3                                     0
# 7                                     5                                     0
# 8                                     6                                     0
# 9                                     0                                     0
# 10                                    0                                     0
# 11                                    1                                     0
# 12                                    1                                     0
# 13                                    6                                     0
# 14                                    1                                     0
# 15                                    1                                     0
# 16                                   15                                     0
# 17                                   11                                     0
# 18                                    0                                     0
# 19                                    5                                     0
# 20                                    8                                     0
#
#     Deceleration Zone Count: 1 - 2 m/s/s  \
# 0                                    190
# 1                                    260
# 2                                    117
# 3                                    173
# 4                                     49
# 5                                    221
# 6                                    216
# 7                                    125
# 8                                     93
# 9                                      0
# 10                                   236
# 11                                    45
# 12                                    26
# 13                                   175
# 14                                    23
# 15                                    19
# 16                                   317
# 17                                    99
# 18                                    13
# 19                                   241
# 20                                   120
#
#     Deceleration Zone Count: 2 - 3 m/s/s  \
# 0                                     87
# 1                                    100
# 2                                     59
# 3                                     82
# 4                                     24
# 5                                    107
# 6                                    111
# 7                                     55
# 8                                     58
# 9                                      0
# 10                                   135
# 11                                     9
# 12                                    15
# 13                                   131
# 14                                     9
# 15                                    16
# 16                                   160
# 17                                    59
# 18                                     8
# 19                                   111
# 20                                    70
#
#     Deceleration Zone Count: 3 - 4 m/s/s  Deceleration Zone Count: > 4 m/s/s  \
# 0                                     17                                  13
# 1                                     37                                  10
# 2                                     17                                   5
# 3                                     28                                  10
# 4                                      7                                   2
# 5                                     28                                  13
# 6                                     50                                  31
# 7                                     31                                  20
# 8                                     33                                  18
# 9                                      0                                   0
# 10                                    49                                  27
# 11                                     6                                   1
# 12                                     7                                   2
# 13                                    50                                  20
# 14                                     3                                   0
# 15                                     8                                   3
# 16                                    90                                  28
# 17                                    48                                  26
# 18                                     1                                   2
# 19                                    48                                  23
# 20                                    28                                  14
#
#     Top Decelerations
# 0                  30
# 1                  47
# 2                  22
# 3                  38
# 4                   9
# 5                  41
# 6                  81
# 7                  51
# 8                  51
# 9                   0
# 10                 76
# 11                  7
# 12                  9
# 13                 70
# 14                  3
# 15                 11
# 16                118
# 17                 74
# 18                  3
# 19                 71
# 20                 42
#
# [21 rows x 97 columns]

# %%
Asbury_volume_intensity = Asbury_full[["Player Code", "Minutes Played", "Distance (miles)", "Sprint Distance (yards)", "Power Plays", "Energy (kcal)", "Impacts", "Top Speed (mph)","Distance Per Min (yd/min)", "Power Score (w/kg)", "Player Load", "Work Ratio"]]

# %%
Asbury_cluster = Asbury_volume_intensity.loc[:, Asbury_volume_intensity.columns != 'Player Code']

# %%
Asbury_distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(Asbury_cluster)
    Asbury_distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, Asbury_distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method shwoing the optimal k')
plt.show()

# %%
x_Asbury = Asbury_cluster.values # numpy array
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x_Asbury)
X_norm = pd.DataFrame(x_scaled)

# %%
pca_Asbury = PCA(n_components = 2) # 2D PCA for the plot
reduced_Asbury= pd.DataFrame(pca_Asbury.fit_transform(X_norm))

# %%
kmeans = KMeans(n_clusters=3)
# fit the input data
kmeans = kmeans.fit(reduced_Asbury)
# get the cluster labels
labels = kmeans.predict(reduced_Asbury)
# centroid values
centroid = kmeans.cluster_centers_
# cluster values
clusters = kmeans.labels_.tolist()
# adding names
Asbury_names = Asbury_full['Player Code']

# %%
reduced_Asbury['cluster'] = clusters
reduced_Asbury['names'] = Asbury_names
reduced_Asbury.columns = ['x', 'y', 'cluster', 'names']
reduced_Asbury.head()

# %%
# %matplotlib inline
sns.set(style="white")
ax = sns.lmplot(x="x", y="y", hue='cluster', data = reduced_Asbury, legend= True,
fit_reg=False, height = 15, scatter_kws={"s": 250})
texts = []
for x, y, s in zip(reduced_Asbury.x, reduced_Asbury.y, reduced_Asbury.names):
    texts.append(plt.text(x, y, s))
ax.set(ylim=(-2, 2))
plt.tick_params(labelsize=15)
plt.xlabel(" Asbury PC 1", fontsize = 20)
plt.ylabel(" Asbury PC 2", fontsize = 20)
plt.show()

# %%
Asbury_group_0 = reduced_Asbury[(reduced_Asbury['cluster'] == 0)]
Asbury_group_0

# %%
Asbury_group_1 = reduced_Asbury[(reduced_Asbury['cluster'] == 1)]
Asbury_group_1

# %%
Asbury_group_2 = reduced_Asbury[(reduced_Asbury['cluster'] == 2)]
Asbury_group_2
